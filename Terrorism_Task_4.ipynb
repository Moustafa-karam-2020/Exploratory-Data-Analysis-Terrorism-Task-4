# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv("E:\Data_analysis\Terrorism\globalterrorismdb_0718dist2.csv")

# %%
df.head(10)
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
# 5   1970       1     1       United States                North America
# 6   1970       1     2             Uruguay                South America
# 7   1970       1     2       United States                North America
# 8   1970       1     2       United States                North America
# 9   1970       1     3       United States                North America
#
#     provstate           city   latitude   longitude  \
# 0         NaN  Santo Domingo  18.456792  -69.951164
# 1     Federal    Mexico city  19.371887  -99.086624
# 2      Tarlac        Unknown  15.478598  120.599741
# 3      Attica         Athens  37.997490   23.762728
# 4     Fukouka        Fukouka  33.580412  130.396361
# 5    Illinois          Cairo  37.005105  -89.176269
# 6  Montevideo     Montevideo -34.891151  -56.187214
# 7  California        Oakland  37.791927 -122.225906
# 8   Wisconsin        Madison  43.076592  -89.412488
# 9   Wisconsin        Madison  43.072950  -89.386694
#
#                   attacktype1_txt  ...         natlty1_txt  \
# 0                   Assassination  ...  Dominican Republic
# 1     Hostage Taking (Kidnapping)  ...             Belgium
# 2                   Assassination  ...       United States
# 3               Bombing/Explosion  ...       United States
# 4  Facility/Infrastructure Attack  ...       United States
# 5                   Armed Assault  ...       United States
# 6                   Assassination  ...             Uruguay
# 7               Bombing/Explosion  ...       United States
# 8  Facility/Infrastructure Attack  ...       United States
# 9  Facility/Infrastructure Attack  ...       United States
#
#                                 gname weaptype1_txt  \
# 0                              MANO-D       Unknown
# 1  23rd of September Communist League       Unknown
# 2                             Unknown       Unknown
# 3                             Unknown    Explosives
# 4                             Unknown    Incendiary
# 5                  Black Nationalists      Firearms
# 6                 Tupamaros (Uruguay)      Firearms
# 7                             Unknown    Explosives
# 8                     New Year's Gang    Incendiary
# 9                     New Year's Gang    Incendiary
#
#                     weapsubtype1_txt nkill nkillus  nkillter  nwound  \
# 0                                NaN   1.0     NaN       NaN     0.0
# 1                                NaN   0.0     NaN       NaN     0.0
# 2                                NaN   1.0     NaN       NaN     0.0
# 3             Unknown Explosive Type   NaN     NaN       NaN     NaN
# 4                                NaN   NaN     NaN       NaN     NaN
# 5                   Unknown Gun Type   0.0     0.0       0.0     0.0
# 6  Automatic or Semi-Automatic Rifle   0.0     NaN       NaN     0.0
# 7             Unknown Explosive Type   0.0     0.0       0.0     0.0
# 8       Molotov Cocktail/Petrol Bomb   0.0     0.0       0.0     0.0
# 9                Gasoline or Alcohol   0.0     0.0       0.0     0.0
#
#    nwoundus  nwoundte
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
# 5       0.0       0.0
# 6       NaN       NaN
# 7       0.0       0.0
# 8       0.0       0.0
# 9       0.0       0.0
#
# [10 rows x 22 columns]

# %%
df.dtypes
# Out:
# iyear                 int64
# imonth                int64
# iday                  int64
# country_txt          object
# region_txt           object
# provstate            object
# city                 object
# latitude            float64
# longitude           float64
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# natlty1_txt          object
# gname                object
# weaptype1_txt        object
# weapsubtype1_txt     object
# nkill               float64
# nkillus             float64
# nkillter            float64
# nwound              float64
# nwoundus            float64
# nwoundte            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   country_txt       181691 non-null  object
#  4   region_txt        181691 non-null  object
#  5   provstate         181270 non-null  object
#  6   city              181257 non-null  object
#  7   latitude          177135 non-null  float64
#  8   longitude         177134 non-null  float64
#  9   attacktype1_txt   181691 non-null  object
#  10  targtype1_txt     181691 non-null  object
#  11  targsubtype1_txt  171318 non-null  object
#  12  natlty1_txt       180132 non-null  object
#  13  gname             181691 non-null  object
#  14  weaptype1_txt     181691 non-null  object
#  15  weapsubtype1_txt  160923 non-null  object
#  16  nkill             171378 non-null  float64
#  17  nkillus           117245 non-null  float64
#  18  nkillter          114733 non-null  float64
#  19  nwound            165380 non-null  float64
#  20  nwoundus          116989 non-null  float64
#  21  nwoundte          112548 non-null  float64
# dtypes: float64(8), int64(3), object(11)
# memory usage: 30.5+ MB

# %%
df.isnull().sum()
# Out:
# iyear                   0
# imonth                  0
# iday                    0
# country_txt             0
# region_txt              0
# provstate             421
# city                  434
# latitude             4556
# longitude            4557
# attacktype1_txt         0
# targtype1_txt           0
# targsubtype1_txt    10373
# natlty1_txt          1559
# gname                   0
# weaptype1_txt           0
# weapsubtype1_txt    20768
# nkill               10313
# nkillus             64446
# nkillter            66958
# nwound              16311
# nwoundus            64702
# nwoundte            69143
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# iyear               0
# imonth              0
# iday                0
# country_txt         0
# region_txt          0
# provstate           0
# city                0
# latitude            0
# longitude           0
# attacktype1_txt     0
# targtype1_txt       0
# targsubtype1_txt    0
# natlty1_txt         0
# gname               0
# weaptype1_txt       0
# weapsubtype1_txt    0
# nkill               0
# nkillus             0
# nkillter            0
# nwound              0
# nwoundus            0
# nwoundte            0
# dtype: int64

# %%
df.shape
# Out:
# (90949, 22)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (87986, 22)

# %%
df.describe()
# Out:
#               iyear        imonth          iday      latitude     longitude  \
# count  87986.000000  87986.000000  87986.000000  87986.000000  87986.000000
# mean    2011.235742      6.460619     15.575569     26.911017     49.888730
# std        6.355565      3.386551      8.811803     13.563055     40.428863
# min     1970.000000      1.000000      0.000000    -42.884049   -157.818968
# 25%     2009.000000      4.000000      8.000000     18.389302     37.762325
# 50%     2013.000000      6.000000     15.000000     32.777344     44.679516
# 75%     2015.000000      9.000000     23.000000     34.346722     71.163803
# max     2017.000000     12.000000     31.000000     74.633553    178.441900
#
#               nkill       nkillus      nkillter        nwound      nwoundus  \
# count  87986.000000  87986.000000  87986.000000  87986.000000  87986.000000
# mean       2.013093      0.013661      0.295479      3.676130      0.027777
# std        7.217770      0.625767      2.600379     14.240864      2.318995
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        2.000000      0.000000      0.000000      3.000000      0.000000
# max      670.000000    168.000000    500.000000   1500.000000    650.000000
#
#            nwoundte
# count  87986.000000
# mean       0.093844
# std        1.510028
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      200.000000

# %%
df.corr()
# Out:
#               iyear    imonth      iday  latitude  longitude     nkill  \
# iyear      1.000000 -0.001155  0.022821 -0.042238   0.324595  0.013194
# imonth    -0.001155  1.000000  0.009638  0.006727   0.003299  0.006669
# iday       0.022821  0.009638  1.000000  0.007585   0.008292  0.002133
# latitude  -0.042238  0.006727  0.007585  1.000000  -0.132517  0.004936
# longitude  0.324595  0.003299  0.008292 -0.132517   1.000000 -0.010634
# nkill      0.013194  0.006669  0.002133  0.004936  -0.010634  1.000000
# nkillus   -0.023846  0.000093 -0.000478  0.009735  -0.031827  0.090789
# nkillter   0.039956 -0.000728 -0.004145  0.015390   0.011414  0.409930
# nwound    -0.011697  0.006046  0.000847  0.032358  -0.002071  0.515029
# nwoundus  -0.021166 -0.000987  0.000697  0.006073  -0.026219  0.080202
# nwoundte   0.026062 -0.000559  0.001060  0.017187   0.018084  0.239543
#
#             nkillus  nkillter    nwound  nwoundus  nwoundte
# iyear     -0.023846  0.039956 -0.011697 -0.021166  0.026062
# imonth     0.000093 -0.000728  0.006046 -0.000987 -0.000559
# iday      -0.000478 -0.004145  0.000847  0.000697  0.001060
# latitude   0.009735  0.015390  0.032358  0.006073  0.017187
# longitude -0.031827  0.011414 -0.002071 -0.026219  0.018084
# nkill      0.090789  0.409930  0.515029  0.080202  0.239543
# nkillus    1.000000  0.001256  0.153762  0.926222 -0.000683
# nkillter   0.001256  1.000000  0.110051  0.000237  0.633717
# nwound     0.153762  0.110051  1.000000  0.165124  0.110808
# nwoundus   0.926222  0.000237  0.165124  1.000000  0.000453
# nwoundte  -0.000683  0.633717  0.110808  0.000453  1.000000

# %%
sns.regplot(df['nwound'],df['nkill'],fit_reg=False)
# Out:
# E:\Newfolder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nwound', ylabel='nkill'>

# %%
sns.regplot(df['nwoundus'],df['nkillus'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='nwoundus', ylabel='nkillus'>

# %%
sns.regplot(df['nwoundus'],df['nkill'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='nwoundus', ylabel='nkill'>

# %%
sns.regplot(df['nwoundte'],df['nkillter'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='nwoundte', ylabel='nkillter'>

# %%
attacks=df["iyear"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"iyear","iyear":"Attacks"}).set_index("iyear")
attacks.head()
# Out:
#        Attacks
# iyear
# 1970       359
# 1971       136
# 1972        65
# 1973        25
# 1974        33

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
df.to_csv('Terrorism Final.csv',index=False)

# %% [markdown]
# ![4.jpg](attachment:4.jpg)
